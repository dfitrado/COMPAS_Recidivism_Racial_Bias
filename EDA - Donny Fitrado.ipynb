# %% [markdown]
# # Exploratory Data Analysis (EDA) on Compas Dataset
# ###  By Donny Fitrado

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
compas_raw = pd.read_csv('data/compas-scores-raw.csv')

# %%
compas_raw.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ...  RecSupervisionLevel  \
# 0          Male        Caucasian    12/05/92  ...                    1
# 1          Male        Caucasian    12/05/92  ...                    1
# 2          Male        Caucasian    12/05/92  ...                    1
# 3          Male        Caucasian    09/16/84  ...                    1
# 4          Male        Caucasian    09/16/84  ...                    1
#
#   RecSupervisionLevelText Scale_ID                DisplayText RawScore  \
# 0                     Low        7           Risk of Violence    -2.08
# 1                     Low        8         Risk of Recidivism    -1.06
# 2                     Low       18  Risk of Failure to Appear    15.00
# 3                     Low        7           Risk of Violence    -2.84
# 4                     Low        8         Risk of Recidivism    -1.50
#
#   DecileScore ScoreText AssessmentType  IsCompleted IsDeleted
# 0           4       Low            New            1         0
# 1           2       Low            New            1         0
# 2           1       Low            New            1         0
# 3           2       Low            New            1         0
# 4           1       Low            New            1         0
#
# [5 rows x 28 columns]

# %%
compas_raw.shape
# Out:
# (60843, 28)

# %%
compas_raw.columns
# Out:
# Index(['Person_ID', 'AssessmentID', 'Case_ID', 'Agency_Text', 'LastName',
#        'FirstName', 'MiddleName', 'Sex_Code_Text', 'Ethnic_Code_Text',
#        'DateOfBirth', 'ScaleSet_ID', 'ScaleSet', 'AssessmentReason',
#        'Language', 'LegalStatus', 'CustodyStatus', 'MaritalStatus',
#        'Screening_Date', 'RecSupervisionLevel', 'RecSupervisionLevelText',
#        'Scale_ID', 'DisplayText', 'RawScore', 'DecileScore', 'ScoreText',
#        'AssessmentType', 'IsCompleted', 'IsDeleted'],
#       dtype='object')

# %%
compas_raw['Ethnic_Code_Text'].unique()
# Out:
# array(['Caucasian', 'African-American', 'Hispanic', 'Other', 'Asian',
#        'African-Am', 'Native American', 'Oriental', 'Arabic'],
#       dtype=object)

# %%
compas_raw.loc[compas_raw['Ethnic_Code_Text'] == 'African-Am', 'Ethnic_Code_Text'] = 'African-American'

# %%
raw_sex = compas_raw.loc[:,["Sex_Code_Text"]]
raw_sex_grouped = raw_sex.groupby(["Sex_Code_Text"]).size().reset_index()
raw_sex_grouped.columns = ["Sex_Code_Text","count"]
raw_sex_grouped
# Out:
#   Sex_Code_Text  count
# 0        Female  13329
# 1          Male  47514

# %%
plt.pie(raw_sex_grouped['count'], labels=raw_sex_grouped['Sex_Code_Text']);

# %%
raw_ethnic = compas_raw.loc[:,["Ethnic_Code_Text"]]
raw_ethnic_grouped = raw_ethnic.groupby(["Ethnic_Code_Text"]).size().reset_index()
raw_ethnic_grouped.columns = ["Ethnic_Code_Text","count"]
raw_ethnic_grouped
# Out:
#    Ethnic_Code_Text  count
# 0  African-American  27069
# 1            Arabic     75
# 2             Asian    324
# 3         Caucasian  21783
# 4          Hispanic   8742
# 5   Native American    219
# 6          Oriental     39
# 7             Other   2592

# %%
sns.barplot(y = 'Ethnic_Code_Text', x = 'count', data = raw_ethnic_grouped.sort_values('count', ascending=False), palette='rainbow')
plt.xlabel('Count')
plt.ylabel('Race');

# %%
raw_english = compas_raw.loc[:,["Language"]]
raw_english_grouped = raw_english.groupby(["Language"]).size().reset_index()
raw_english_grouped.columns = ["Language","count"]
raw_english_grouped
# Out:
#   Language  count
# 0  English  60591
# 1  Spanish    252

# %%
plt.pie(raw_english_grouped['count'], labels=raw_english_grouped['Language']);

# %%
compas_raw["DateOfBirth"] = pd.to_datetime(compas_raw["DateOfBirth"])
compas_raw.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ...  RecSupervisionLevel  \
# 0          Male        Caucasian  1992-12-05  ...                    1
# 1          Male        Caucasian  1992-12-05  ...                    1
# 2          Male        Caucasian  1992-12-05  ...                    1
# 3          Male        Caucasian  1984-09-16  ...                    1
# 4          Male        Caucasian  1984-09-16  ...                    1
#
#   RecSupervisionLevelText Scale_ID                DisplayText RawScore  \
# 0                     Low        7           Risk of Violence    -2.08
# 1                     Low        8         Risk of Recidivism    -1.06
# 2                     Low       18  Risk of Failure to Appear    15.00
# 3                     Low        7           Risk of Violence    -2.84
# 4                     Low        8         Risk of Recidivism    -1.50
#
#   DecileScore ScoreText AssessmentType  IsCompleted IsDeleted
# 0           4       Low            New            1         0
# 1           2       Low            New            1         0
# 2           1       Low            New            1         0
# 3           2       Low            New            1         0
# 4           1       Low            New            1         0
#
# [5 rows x 28 columns]

# %%
compas_raw["Age"] = compas_raw["DateOfBirth"].apply(lambda x : (pd.datetime(2016,5,23).year - x.year))
compas_raw.Age.unique()
# Out:
# array([ 24,  32,  22,  31, -50,  23,  44,  30,  36,  38,  28,  37,  46,
#         25,  41,  43,  35,  27, -44, -51, -39,  42,  29, -27,  39,  33,
#        -52,  34,  45, -43, -31, -46,  26, -49, -47, -48, -28, -38, -37,
#        -40, -17, -45, -53,  20,  40, -34, -42, -26, -41, -35, -13,  21,
#        -30, -32, -29, -24, -33, -36, -22, -21, -25, -19, -16,  -2, -20,
#         19, -23,  -9, -14,  -3,  18], dtype=int64)

# %%
bins = [18, 25, 30, 35, 40, 45, 50]
labels = ['18-24','25-29','30-34','35-39','40-44','45-49']
compas_raw['Age_Group'] = pd.cut(compas_raw.Age, bins, labels = labels, include_lowest = True)
compas_raw.Age_Group.head()
# Out:
# 0    18-24
# 1    18-24
# 2    18-24
# 3    30-34
# 4    30-34
# Name: Age_Group, dtype: category
# Categories (6, object): [18-24 < 25-29 < 30-34 < 35-39 < 40-44 < 45-49]

# %%
raw_marriage = compas_raw.loc[:,["MaritalStatus"]]
raw_marriage_grouped = raw_marriage.groupby(["MaritalStatus"]).size().reset_index()
raw_marriage_grouped.columns = ["MaritalStatus","count"]
raw_marriage_grouped
# Out:
#        MaritalStatus  count
# 0           Divorced   3879
# 1            Married   8172
# 2          Separated   1803
# 3  Significant Other   1260
# 4             Single  45126
# 5            Unknown    213
# 6            Widowed    390

# %%
sns.barplot(y = 'MaritalStatus', x = 'count', data = raw_marriage_grouped.sort_values('count', ascending=False),palette='rainbow')
plt.xlabel('Count')
plt.ylabel('Marital Status');

# %%
raw_legalstatus = compas_raw.loc[:,["LegalStatus"]]
raw_legalstatus_grouped = raw_legalstatus.groupby(["LegalStatus"]).size().reset_index()
raw_legalstatus_grouped.columns = ["LegalStatus","count"]
raw_legalstatus_grouped
# Out:
#            LegalStatus  count
# 0  Conditional Release    420
# 1  Deferred Sentencing     12
# 2                Other   4356
# 3      Parole Violator     18
# 4        Post Sentence  18333
# 5             Pretrial  37578
# 6   Probation Violator    126

# %%
sns.barplot(y = 'LegalStatus', x = 'count', data = raw_legalstatus_grouped.sort_values('count', ascending=False),palette='rainbow')
plt.xlabel('Count')
plt.ylabel('Legal Status');

# %%
pd.crosstab(compas_raw.Ethnic_Code_Text, compas_raw.LegalStatus)[['Pretrial', 'Post Sentence', 'Conditional Release', 'Other',
       'Probation Violator', 'Parole Violator', 'Deferred Sentencing']]
# Out:
# LegalStatus       Pretrial  Post Sentence  Conditional Release  Other  \
# Ethnic_Code_Text
# African-American     18978           6612                  177   1218
# Arabic                  39             33                    3      0
# Asian                  129            162                    0     33
# Caucasian            12771           7551                  162   1260
# Hispanic              3450           3456                   75   1728
# Native American        129             69                    0     21
# Oriental                12             27                    0      0
# Other                 2070            423                    3     96
#
# LegalStatus       Probation Violator  Parole Violator  Deferred Sentencing
# Ethnic_Code_Text
# African-American                  75                0                    9
# Arabic                             0                0                    0
# Asian                              0                0                    0
# Caucasian                         27                9                    3
# Hispanic                          24                9                    0
# Native American                    0                0                    0
# Oriental                           0                0                    0
# Other                              0                0                    0

# %%
pd.crosstab(compas_raw.Ethnic_Code_Text, compas_raw.CustodyStatus)[['Jail Inmate', 'Probation', 'Pretrial Defendant',
       'Residential Program', 'Prison Inmate', 'Parole']]
# Out:
# CustodyStatus     Jail Inmate  Probation  Pretrial Defendant  \
# Ethnic_Code_Text
# African-American        15768       7950                3306
# Arabic                     27         36                  12
# Asian                     108        192                  24
# Caucasian                9741       8901                3096
# Hispanic                 2460       5256                1017
# Native American           105         90                  24
# Oriental                   12         27                   0
# Other                    1908        516                 165
#
# CustodyStatus     Residential Program  Prison Inmate  Parole
# Ethnic_Code_Text
# African-American                   24             15       6
# Arabic                              0              0       0
# Asian                               0              0       0
# Caucasian                          30              0      15
# Hispanic                            9              0       0
# Native American                     0              0       0
# Oriental                            0              0       0
# Other                               3              0       0

# %%
compas_raw["CustodyStatus"].unique()
# Out:
# array(['Jail Inmate', 'Probation', 'Pretrial Defendant',
#        'Residential Program', 'Prison Inmate', 'Parole'], dtype=object)

# %%
pd.crosstab(compas_raw.Ethnic_Code_Text, compas_raw.CustodyStatus)[['Jail Inmate', 'Probation', 'Pretrial Defendant',
       'Residential Program', 'Prison Inmate', 'Parole']]
# Out:
# CustodyStatus     Jail Inmate  Probation  Pretrial Defendant  \
# Ethnic_Code_Text
# African-American        15768       7950                3306
# Arabic                     27         36                  12
# Asian                     108        192                  24
# Caucasian                9741       8901                3096
# Hispanic                 2460       5256                1017
# Native American           105         90                  24
# Oriental                   12         27                   0
# Other                    1908        516                 165
#
# CustodyStatus     Residential Program  Prison Inmate  Parole
# Ethnic_Code_Text
# African-American                   24             15       6
# Arabic                              0              0       0
# Asian                               0              0       0
# Caucasian                          30              0      15
# Hispanic                            9              0       0
# Native American                     0              0       0
# Oriental                            0              0       0
# Other                               3              0       0

# %%
raw_custody = compas_raw.loc[:,["CustodyStatus"]]
raw_custody_grouped = raw_custody.groupby(["CustodyStatus"]).size().reset_index()
raw_custody_grouped.columns = ["CustodyStatus","count"]
raw_custody_grouped
# Out:
#          CustodyStatus  count
# 0          Jail Inmate  30129
# 1               Parole     21
# 2   Pretrial Defendant   7644
# 3        Prison Inmate     15
# 4            Probation  22968
# 5  Residential Program     66

# %%
sns.barplot(y = 'CustodyStatus', x = 'count', data = raw_custody_grouped.sort_values('count', ascending=False), palette='rainbow')
plt.xlabel('Count')
plt.ylabel('Custody Status');

# %%
raw_agency = compas_raw.loc[:,["Agency_Text"]]
raw_agency_grouped = raw_agency.groupby(["Agency_Text"]).size().reset_index()
raw_agency_grouped.columns = ["Agency_Text","count"]
raw_agency_grouped
# Out:
#       Agency_Text  count
# 0  Broward County    123
# 1            DRRD    564
# 2        PRETRIAL  41100
# 3       Probation  19056

# %%
raw_reason = compas_raw.loc[:,["AssessmentReason"]]
raw_reason_grouped = raw_reason.groupby(["AssessmentReason"]).size().reset_index()
raw_reason_grouped.columns = ["AssessmentReason","count"]
raw_reason_grouped
# Out:
#   AssessmentReason  count
# 0           Intake  60843

# %%
pd.crosstab(compas_raw.Ethnic_Code_Text, compas_raw.AssessmentType)
# Out:
# AssessmentType    Copy    New
# Ethnic_Code_Text
# African-American  2886  24183
# Arabic               3     72
# Asian               12    312
# Caucasian         1332  20451
# Hispanic           312   8430
# Native American     18    201
# Oriental             0     39
# Other              141   2451

# %%
pd.crosstab(compas_raw.Ethnic_Code_Text, compas_raw.AssessmentType, normalize="columns")
# Out:
# AssessmentType        Copy       New
# Ethnic_Code_Text
# African-American  0.613520  0.430770
# Arabic            0.000638  0.001283
# Asian             0.002551  0.005558
# Caucasian         0.283163  0.364292
# Hispanic          0.066327  0.150163
# Native American   0.003827  0.003580
# Oriental          0.000000  0.000695
# Other             0.029974  0.043659

# %%
chart1 = sns.catplot(x="Ethnic_Code_Text", y="DecileScore", hue="DisplayText", data=compas_raw, kind="bar")
chart1.set_xticklabels(rotation=50, horizontalalignment='right')

# %%
ct1 = pd.crosstab(compas_raw.Ethnic_Code_Text, compas_raw.RecSupervisionLevelText)[["Low","Medium","Medium with Override Consideration","High"]]
ct1
# Out:
# RecSupervisionLevelText    Low  Medium  Medium with Override Consideration  \
# Ethnic_Code_Text
# African-American         12831    5976                                5232
# Arabic                      51      15                                   6
# Asian                      288      18                                   9
# Caucasian                16155    3075                                1881
# Hispanic                  6903    1026                                 537
# Native American            108      51                                  42
# Oriental                    36       0                                   0
# Other                     2100     315                                 120
#
# RecSupervisionLevelText  High
# Ethnic_Code_Text
# African-American         3030
# Arabic                      3
# Asian                       9
# Caucasian                 672
# Hispanic                  276
# Native American            18
# Oriental                    3
# Other                      57

# %%
compas_two_year = pd.read_csv('data/compas-scores-two-years.csv')
compas_two_year_violent = pd.read_csv('data/compas-scores-two-years-violent.csv')

# %%
compas_two_year.shape
# Out:
# (7214, 53)

# %%
compas_two_year.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  ...  v_decile_score  \
# 0  1947-04-18   69  Greater than 45             Other  ...               1
# 1  1982-01-22   34          25 - 45  African-American  ...               1
# 2  1991-05-14   24     Less than 25  African-American  ...               3
# 3  1993-01-21   23     Less than 25  African-American  ...               6
# 4  1973-01-22   43          25 - 45             Other  ...               1
#
#    v_score_text  v_screening_date  in_custody  out_custody  priors_count.1  \
# 0           Low        2013-08-14  2014-07-07   2014-07-14               0
# 1           Low        2013-01-27  2013-01-26   2013-02-05               0
# 2           Low        2013-04-14  2013-06-16   2013-06-16               4
# 3        Medium        2013-01-13         NaN          NaN               1
# 4           Low        2013-03-26         NaN          NaN               2
#
#   start   end event two_year_recid
# 0     0   327     0              0
# 1     9   159     1              1
# 2     0    63     0              1
# 3     0  1174     0              0
# 4     0  1102     0              0
#
# [5 rows x 53 columns]

# %%
compas_two_year_violent.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   5         marcu brown   marcu        brown            2013-01-13  Male
# 3   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
# 4   7        marsha miles  marsha        miles            2013-11-30  Male
#
#           dob  age          age_cat              race  ...  v_score_text  \
# 0  1947-04-18   69  Greater than 45             Other  ...           Low
# 1  1982-01-22   34          25 - 45  African-American  ...           Low
# 2  1993-01-21   23     Less than 25  African-American  ...        Medium
# 3  1973-01-22   43          25 - 45             Other  ...           Low
# 4  1971-08-22   44          25 - 45             Other  ...           Low
#
#    v_screening_date  in_custody  out_custody  priors_count.1  start   end  \
# 0        2013-08-14  2014-07-07   2014-07-14               0      0   327
# 1        2013-01-27  2013-01-26   2013-02-05               0      9   159
# 2        2013-01-13         NaN          NaN               1      0  1174
# 3        2013-03-26         NaN          NaN               2      0  1102
# 4        2013-11-30  2013-11-30   2013-12-01               0      1   853
#
#   event two_year_recid two_year_recid.1
# 0     0              0                0
# 1     1              1                1
# 2     0              0                0
# 3     0              0                0
# 4     0              0                0
#
# [5 rows x 54 columns]

# %%
compas_two_year_violent.shape
# Out:
# (4743, 54)

# %%
violent_sex = compas_two_year_violent.loc[:,["sex"]]
violent_sex_grouped = violent_sex.groupby(["sex"]).size().reset_index()
violent_sex_grouped.columns = ["sex","count"]
violent_sex_grouped
# Out:
#       sex  count
# 0  Female    997
# 1    Male   3746

# %%
sns.distplot(compas_two_year_violent['age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency');

# %%
age_cat_grouped = compas_two_year_violent.groupby(["age_cat"]).size().reset_index()
age_cat_grouped.columns = ["age_cat","count"]
sns.barplot(y = 'age_cat', x = 'count', data = age_cat_grouped, palette='rainbow');

# %%
race_grouped = compas_two_year_violent.groupby(["race"]).size().reset_index()
race_grouped.columns = ["race","count"]
sns.barplot(y = 'race', x = 'count', data = race_grouped.sort_values('count', ascending=False),palette='rainbow');

# %%
compas_raw.to_csv("data/compas_v2.csv", sep=',')
